# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepDatascientist/Projects---SQL---MachineLearning--Python/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the Pytorch module
import torch

# %%
# Importing detecto module

from detecto import core,utils,visualize
image = utils.read_image('Apple.jpeg')
model= core.Model()
labels,boxes,scores= model.predict_top(image)
visualize.show_labeled_image(image,boxes,labels)

# %%
from google.colab import drive
drive.mount('/content/drive')
